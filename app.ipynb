# %%
import google.generativeai as genai
from PIL import Image
import json

# Configure API key
genai.configure(api_key="AIzaSyC99TtHQzF-0ReIExaPVi1X2wE8qbPcty4")

# Use the correct model
model = genai.GenerativeModel("gemini-1.5-pro")  # Gemini 2.5 may not be publicly available

# Load the image properly
image_path = r"c:\Users\User\Downloads\tomanthracnose.jpg"
image = Image.open(image_path)

# Prompt
prompt = """
Give the segmentation masks for the objects.
Output a JSON list of segmentation masks where each entry contains the 2D
bounding box in the key "box_2d", the segmentation mask in key "mask", and
the text label in the key "label". Use descriptive labels.
"""

# Generate content with prompt and image
response = model.generate_content(
    contents=[prompt, image],
)

# Output response
print(response.text)
# Out:
# ```json
# [
#   {
#     "box_2d": [
#       140,
#       120,
#       280,
#       260
#     ],
#     "mask": [
#       [140,120],
#       [145, 115],
#       [150,112],
#       [160,110],
#       [180,110],
#       [200,115],
#       [220,125],
#       [240,140],
#       [260,160],
#       [280,190],
#       [280,220],
#       [270,240],
#       [260,250],
#       [250,260],
#       [230,260],
#       [210,250],
#       [190,240],
#       [170,220],
#       [160,210],
#       [150,200],
#       [145,180],
#       [140,160]
#
#
#     ],
#     "label": "Tomato Blight Lesion"
#   },
#
#
# {
#     "box_2d": [
#       300,
#       200,
#       450,
#       350
#     ],
#     "mask": [
#        [300,200],
#        [320,190],
#        [340,190],
#        [360,195],
#        [380,200],
#        [400,220],
#        [420,240],
#        [440,270],
#        [450,300],
#        [450,330],
#        [440,340],
#        [430,350],
#        [400,350],
#        [380,340],
#        [360,320],
# ...
